# %%
# %matplotlib inline
import numpy as np
import gzip
import matplotlib.pyplot as plt

# %%
coh = np.load(gzip.open("files/data_0.01_1.0_1000.0_0.008384615384615386_8_.npy.gz", 'rb'))

# %%
plt.plot(coh)
plt.show()

# %%
plt.plot(coh[:100])
plt.show()

# %%
print(type(coh))
print(coh.nbytes)
# Out:
# <class 'numpy.ndarray'>
# 7600
